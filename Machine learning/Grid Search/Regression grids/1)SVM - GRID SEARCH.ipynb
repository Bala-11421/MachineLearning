# %%
#import the libraries

import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import sklearn

# %%
dataset= pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset= pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi','children','sex_male','smoker_yes',]]
dep=dataset['charges']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(indep, dep, test_size=0.33, random_state=0)

# %%
# which is used for get the datas into particular range like -3 to +3

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import  GridSearchCV
from sklearn.svm import SVR 
param_grid = {'kernel':['rbf', 'poly', 'sigmoid', 'linear'],'C':[10,100,1000,2000,30000],'gamma':['auto', 'scale']}

grid = GridSearchCV(SVR(), param_grid, refit = True , verbose = 3, n_jobs=-1)

#fitting the model for grid

grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 30000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
# print the best parameter after tuning 
#print (grid.best_params)

re = grid.cv_results_
 
print("the R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# the R_score value for best parameter {'C': 30000, 'gamma': 'scale', 'kernel': 'rbf'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.096866      0.024996         0.065620        0.011690      10
# 1        0.087491      0.012499         0.012499        0.006249      10
# 2        0.103119      0.023385         0.018745        0.006253      10
# 3        0.065616      0.006249         0.003125        0.006250      10
# 4        0.074991      0.006249         0.034372        0.006249      10
# 5        0.081242      0.030294         0.024997        0.035075      10
# 6        0.156320      0.032644         0.025061        0.018872      10
# 7        0.084610      0.031065         0.012497        0.011691      10
# 8        0.090598      0.030311         0.040664        0.012468     100
# 9        0.084761      0.007341         0.012498        0.006249     100
# 10       0.118802      0.021132         0.025171        0.018980     100
# 11       0.084723      0.007458         0.028301        0.049062     100
# 12       0.078338      0.009772         0.056545        0.021480     100
# 13       0.075004      0.022895         0.034505        0.045974     100
# 14       0.147942      0.045041         0.022772        0.038127     100
# 15       0.103806      0.042931         0.012530        0.006266     100
# 16       0.094398      0.017277         0.040682        0.018680    1000
# 17       0.116190      0.035322         0.009430        0.007700    1000
# 18       0.154015      0.042831         0.015763        0.010008    1000
# 19       0.128601      0.062293         0.012554        0.011780    1000
# 20       0.125446      0.044310         0.053182        0.023399    1000
# 21       0.134676      0.035270         0.006345        0.012689    1000
# 22       0.116416      0.030573         0.031279        0.017115    1000
# 23       0.100353      0.040677         0.012530        0.011765    1000
# 24       0.147463      0.037947         0.034550        0.023342    2000
# 25       0.376802      0.183304         0.031230        0.032754    2000
# 26       0.141189      0.061244         0.018846        0.006204    2000
# 27       0.186863      0.103292         0.013857        0.008649    2000
# 28       0.122400      0.052678         0.050513        0.023013    2000
# 29       0.544639      0.312114         0.003124        0.006249    2000
# 30       0.140360      0.072206         0.072066        0.112883    2000
# 31       0.367825      0.286594         0.009166        0.012003    2000
# 32       1.990682      0.911194         0.088031        0.036766   30000
# 33       4.911171      2.821113         0.009425        0.007696   30000
# 34       0.304846      0.164276         0.116048        0.032811   30000
# 35       2.016128      0.509829         0.081732        0.126213   30000
# 36       1.939588      0.505780         0.069238        0.041745   30000
# 37       4.340519      3.426037         0.036510        0.026954   30000
# 38       0.427246      0.137403         0.169755        0.104464   30000
# 39       1.647195      0.252861         0.052025        0.062657   30000
#
#    param_gamma param_kernel  \
# 0         auto          rbf
# 1         auto         poly
# 2         auto      sigmoid
# 3         auto       linear
# 4        scale          rbf
# 5        scale         poly
# 6        scale      sigmoid
# 7        scale       linear
# 8         auto          rbf
# 9         auto         poly
# 10        auto      sigmoid
# 11        auto       linear
# 12       scale          rbf
# 13       scale         poly
# 14       scale      sigmoid
# 15       scale       linear
# 16        auto          rbf
# 17        auto         poly
# 18        auto      sigmoid
# 19        auto       linear
# 20       scale          rbf
# 21       scale         poly
# 22       scale      sigmoid
# 23       scale       linear
# 24        auto          rbf
# 25        auto         poly
# 26        auto      sigmoid
# 27        auto       linear
# 28       scale          rbf
# 29       scale         poly
# 30       scale      sigmoid
# 31       scale       linear
# 32        auto          rbf
# 33        auto         poly
# 34        auto      sigmoid
# 35        auto       linear
# 36       scale          rbf
# 37       scale         poly
# 38       scale      sigmoid
# 39       scale       linear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}          -0.002037
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.049721
# 2     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.046225
# 3      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.390162
# 4        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}          -0.001837
# 5       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.046151
# 6    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.045464
# 7     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.390162
# 8        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.307188
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.553649
# 10   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.501068
# 11    {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.610157
# 12      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.308503
# 13     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.543867
# 14  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.502412
# 15   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.610157
# 16      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.753782
# 17     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.826632
# 18  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.467915
# 19   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.712363
# 20     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.754332
# 21    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.825424
# 22  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.262792
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.712363
# 24      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.815754
# 25     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.832084
# 26  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}          -0.080092
# 27   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.698071
# 28     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.816178
# 29    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.832146
# 30  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...          -0.622769
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.698071
# 32     {'C': 30000, 'gamma': 'auto', 'kernel': 'rbf'}           0.834548
# 33    {'C': 30000, 'gamma': 'auto', 'kernel': 'poly'}           0.830307
# 34  {'C': 30000, 'gamma': 'auto', 'kernel': 'sigmo...        -222.358738
# 35  {'C': 30000, 'gamma': 'auto', 'kernel': 'linear'}           0.697952
# 36    {'C': 30000, 'gamma': 'scale', 'kernel': 'rbf'}           0.834639
# 37   {'C': 30000, 'gamma': 'scale', 'kernel': 'poly'}           0.830308
# 38  {'C': 30000, 'gamma': 'scale', 'kernel': 'sigm...        -211.810570
# 39  {'C': 30000, 'gamma': 'scale', 'kernel': 'line...           0.697952
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.026336          -0.135126          -0.083512
# 1            0.080350          -0.070752          -0.010636
# 2            0.085922          -0.082880          -0.027038
# 3            0.473576           0.272390           0.339386
# 4            0.026207          -0.135217          -0.083504
# 5            0.082480          -0.069101          -0.010784
# 6            0.086434          -0.082653          -0.027065
# 7            0.473576           0.272390           0.339386
# 8            0.331844           0.138775           0.208026
# 9            0.568310           0.461586           0.530450
# 10           0.557035           0.424297           0.464144
# 11           0.643653           0.554462           0.583569
# 12           0.330985           0.138250           0.208081
# 13           0.572925           0.465448           0.530126
# 14           0.558419           0.426594           0.464074
# 15           0.643653           0.554462           0.583569
# 16           0.725578           0.681342           0.704903
# 17           0.793068           0.815025           0.799938
# 18           0.354563           0.299646           0.264536
# 19           0.617944           0.573310           0.566719
# 20           0.725217           0.680944           0.704939
# 21           0.793275           0.815697           0.800016
# 22           0.407965           0.296616           0.270362
# 23           0.617944           0.573310           0.566719
# 24           0.773646           0.807802           0.784903
# 25           0.792861           0.834562           0.795837
# 26          -0.513678          -0.380657          -0.471484
# 27           0.612719           0.574947           0.565813
# 28           0.773423           0.807512           0.784920
# 29           0.792903           0.834566           0.795928
# 30          -0.458673          -0.414534          -0.447349
# 31           0.612719           0.574947           0.565813
# 32           0.810681           0.853238           0.809614
# 33           0.788330           0.837967           0.784539
# 34        -267.673311        -188.701576        -204.837437
# 35           0.609315           0.575779           0.562414
# 36           0.810768           0.853259           0.809613
# 37           0.788328           0.837968           0.784549
# 38        -264.198598        -204.563910        -199.244505
# 39           0.609315           0.575779           0.562414
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.103522        -0.059572        0.061488               35
# 1           -0.050070        -0.000277        0.057539               32
# 2           -0.051404        -0.005835        0.062596               34
# 3            0.300548         0.355213        0.071175               25
# 4           -0.103552        -0.059581        0.061515               36
# 5           -0.049628        -0.000177        0.057073               31
# 6           -0.051309        -0.005826        0.062553               33
# 7            0.300548         0.355213        0.071175               25
# 8            0.163605         0.229888        0.076868               29
# 9            0.414650         0.505729        0.058426               21
# 10           0.423104         0.473930        0.050568               24
# 11           0.537781         0.585925        0.038034               19
# 12           0.163407         0.229845        0.077063               30
# 13           0.415878         0.505649        0.057028               22
# 14           0.423278         0.474956        0.050691               23
# 15           0.537781         0.585925        0.038034               19
# 16           0.615792         0.696279        0.046777               11
# 17           0.722323         0.791397        0.036460                7
# 18           0.371545         0.351641        0.069592               27
# 19           0.556345         0.605336        0.057499               13
# 20           0.615656         0.696218        0.046942               12
# 21           0.722352         0.791353        0.036314                8
# 22           0.356610         0.318869        0.055417               28
# 23           0.556345         0.605336        0.057499               13
# 24           0.711846         0.778790        0.036752                9
# 25           0.745024         0.800074        0.032602                4
# 26          -0.077518        -0.304686        0.189377               37
# 27           0.557307         0.601772        0.051736               15
# 28           0.711778         0.778762        0.036823               10
# 29           0.745097         0.800128        0.032586                3
# 30          -0.068937        -0.402452        0.181711               38
# 31           0.557307         0.601772        0.051736               15
# 32           0.741297         0.809876        0.037928                2
# 33           0.756398         0.799508        0.030447                6
# 34        -176.568899      -212.027992       31.800311               40
# 35           0.557734         0.600639        0.051894               17
# 36           0.741260         0.809908        0.037958                1
# 37           0.756397         0.799510        0.030447                5
# 38        -151.842317      -206.331980       35.780000               39
# 39           0.557734         0.600639        0.051894               17

# %%
age_input = float(input("Age:"))
bmi_input = float(input("BMI:"))
children_input = float(input("children:"))
sex_male_input = int(input("sex Male 0 or 1:"))
smoker_yes_input=int(input("smoker yes 0 or 1:"))
# Out:
# Age:34
# BMI:45
# children:1
# sex Male 0 or 1:1
# smoker yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])#␣
#change and find it
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[18303.76655706]
