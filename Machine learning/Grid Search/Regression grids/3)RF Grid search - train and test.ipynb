# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
 # Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
 indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
 from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'absolute_error'],
                                'max_features': ['sqrt','log2'],
                                     'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_


print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.109860      0.013959         0.012669        0.006336
# 1       0.980571      0.075815         0.021873        0.012499
# 2       0.093892      0.017258         0.012592        0.006297
# 3       0.914248      0.040213         0.034371        0.015308
# 4       0.297623      0.028202         0.006249        0.007654
# 5       2.579236      0.145682         0.018749        0.006249
# 6       0.290889      0.012713         0.006262        0.007670
# 7       2.160578      0.093626         0.015653        0.000058
#
#   param_criterion param_max_features param_n_estimators  \
# 0   squared_error               sqrt                 10
# 1   squared_error               sqrt                100
# 2   squared_error               log2                 10
# 3   squared_error               log2                100
# 4  absolute_error               sqrt                 10
# 5  absolute_error               sqrt                100
# 6  absolute_error               log2                 10
# 7  absolute_error               log2                100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'max_features':...           0.842703
# 1  {'criterion': 'squared_error', 'max_features':...           0.857411
# 2  {'criterion': 'squared_error', 'max_features':...           0.838641
# 3  {'criterion': 'squared_error', 'max_features':...           0.860473
# 4  {'criterion': 'absolute_error', 'max_features'...           0.833231
# 5  {'criterion': 'absolute_error', 'max_features'...           0.856821
# 6  {'criterion': 'absolute_error', 'max_features'...           0.834608
# 7  {'criterion': 'absolute_error', 'max_features'...           0.854590
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.749117           0.845774           0.819499           0.825116
# 1           0.783681           0.856952           0.830383           0.844031
# 2           0.772989           0.849668           0.821826           0.830004
# 3           0.780718           0.860367           0.829960           0.837361
# 4           0.767068           0.854335           0.814337           0.828530
# 5           0.777779           0.857585           0.829563           0.847664
# 6           0.757116           0.863734           0.807214           0.831461
# 7           0.780959           0.854717           0.827605           0.846790
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.816442        0.035121                8
# 1         0.834492        0.027274                1
# 2         0.822626        0.026483                5
# 3         0.833776        0.029197                3
# 4         0.819500        0.029187                6
# 5         0.833882        0.029813                2
# 6         0.818827        0.035689                7
# 7         0.832932        0.027804                4

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:32
# BMI:32
# Children:1
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:1

# %%
 Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])#␣
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[37367.4101582]
# C:\Users\balaj\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
